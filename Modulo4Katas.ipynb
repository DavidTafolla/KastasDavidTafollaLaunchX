# %% [markdown]
# Ejercicio 1: Transformar cadenas

# %% [markdown]
# Hay varias operaciones que puedes realizar en las cadenas cuando las manipulamos. En este ejercicio, usarás métodos de cadena para modificar el texto con hechos sobre la Luna y luego extraerás información para crear un breve resumen.
#
# El texto con el que trabajarás es el siguiente:

# %%
text = """Interesting facts about the Moon. The Moon is Earth's only satellite. There are several interesting facts about the Moon and how it affects life here on Earth. 
On average, the Moon moves 4cm away from the Earth every year. This yearly drift is not significant enough to cause immediate effects on Earth. The highes"""

# %% [markdown]
# Primero, divide el texto en cada oración para trabajar con su contenido:

# %%
text = """Interesting facts about the Moon. The Moon is Earth's only satellite. There are several interesting facts about the Moon and how it affects life here on Earth. 
On average, the Moon moves 4cm away from the Earth every year. This yearly drift is not significant enough to cause immediate effects on Earth. The highes"""

text.split('. ')
# Out:
# ['Interesting facts about the Moon',
#  "The Moon is Earth's only satellite",
#  'There are several interesting facts about the Moon and how it affects life here on Earth',
#  '\nOn average, the Moon moves 4cm away from the Earth every year',
#  'This yearly drift is not significant enough to cause immediate effects on Earth',
#  'The highes']

# %% [markdown]
# Ahora, define algunas palabras clave para búsqueda que te ayudarán a determinar si una oración contiene un hecho.

# %%
Palabras_claves = ["average", "temperature", "distance"]

# %% [markdown]
# Cre un bucle para imprimir solo datos sobre la Luna que estén relacionados con las palabras clave definidas anteriormente:

# %%
for datos in text:
    for Palabras_claves in text:
        if Palabras_claves in datos:
            print(datos)
            break
# Out:
# I
# n
# t
# e
# r
# e
# s
# t
# i
# n
# g
#
# f
# a
# c
# t
# s
#
# a
# b
# o
# u
# t
#
# t
# h
# e
#
# M
# o
# o
# n
# .
#
# T
# h
# e
#
# M
# o
# o
# n
#
# i
# s
#
# E
# a
# r
# t
# h
# '
# s
#
# o
# n
# l
# y
#
# s
# a
# t
# e
# l
# l
# i
# t
# e
# .
#
# T
# h
# e
# r
# e
#
# a
# r
# e
#
# s
# e
# v
# e
# r
# a
# l
#
# i
# n
# t
# e
# r
# e
# s
# t
# i
# n
# g
#
# f
# a
# c
# t
# s
#
# a
# b
# o
# u
# t
#
# t
# h
# e
#
# M
# o
# o
# n
#
# a
# n
# d
#
# h
# o
# w
#
# i
# t
#
# a
# f
# f
# e
# c
# t
# s
#
# l
# i
# f
# e
#
# h
# e
# r
# e
#
# o
# n
#
# E
# a
# r
# t
# h
# .
#
#
#
# O
# n
#
# a
# v
# e
# r
# a
# g
# e
# ,
#
# t
# h
# e
#
# M
# o
# o
# n
#
# m
# o
# v
# e
# s
#
# 4
# c
# m
#
# a
# w
# a
# y
#
# f
# r
# o
# m
#
# t
# h
# e
#
# E
# a
# r
# t
# h
#
# e
# v
# e
# r
# y
#
# y
# e
# a
# r
# .
#
# T
# h
# i
# s
#
# y
# e
# a
# r
# l
# y
#
# d
# r
# i
# f
# t
#
# i
# s
#
# n
# o
# t
#
# s
# i
# g
# n
# i
# f
# i
# c
# a
# n
# t
#
# e
# n
# o
# u
# g
# h
#
# t
# o
#
# c
# a
# ...

# %% [markdown]
# Finalmente, actualiza el bucle(ciclo) para cambiar C a Celsius:

# %%
for celsisus in text:
    for Palabras_claves in text:
        if Palabras_claves in  celsisus:
            print(celsisus.replace(' C', ' Celsius'))
            break
# Out:
# I
# n
# t
# e
# r
# e
# s
# t
# i
# n
# g
#
# f
# a
# c
# t
# s
#
# a
# b
# o
# u
# t
#
# t
# h
# e
#
# M
# o
# o
# n
# .
#
# T
# h
# e
#
# M
# o
# o
# n
#
# i
# s
#
# E
# a
# r
# t
# h
# '
# s
#
# o
# n
# l
# y
#
# s
# a
# t
# e
# l
# l
# i
# t
# e
# .
#
# T
# h
# e
# r
# e
#
# a
# r
# e
#
# s
# e
# v
# e
# r
# a
# l
#
# i
# n
# t
# e
# r
# e
# s
# t
# i
# n
# g
#
# f
# a
# c
# t
# s
#
# a
# b
# o
# u
# t
#
# t
# h
# e
#
# M
# o
# o
# n
#
# a
# n
# d
#
# h
# o
# w
#
# i
# t
#
# a
# f
# f
# e
# c
# t
# s
#
# l
# i
# f
# e
#
# h
# e
# r
# e
#
# o
# n
#
# E
# a
# r
# t
# h
# .
#
#
#
# O
# n
#
# a
# v
# e
# r
# a
# g
# e
# ,
#
# t
# h
# e
#
# M
# o
# o
# n
#
# m
# o
# v
# e
# s
#
# 4
# c
# m
#
# a
# w
# a
# y
#
# f
# r
# o
# m
#
# t
# h
# e
#
# E
# a
# r
# t
# h
#
# e
# v
# e
# r
# y
#
# y
# e
# a
# r
# .
#
# T
# h
# i
# s
#
# y
# e
# a
# r
# l
# y
#
# d
# r
# i
# f
# t
#
# i
# s
#
# n
# o
# t
#
# s
# i
# g
# n
# i
# f
# i
# c
# a
# n
# t
#
# e
# n
# o
# u
# g
# h
#
# t
# o
#
# c
# a
# ...

# %% [markdown]
# Ejercicio 2: Formateando Cadenas
# Saber cómo dar formato a las cadenas es esencial cuando se presenta información de un programa. Hay algunas maneras diferentes de lograr esto en Python. En este ejercicio, se utilizan variables que contienen datos clave sobre la gravedad en varias lunas y luego se utilizan para dar formato e imprimir la información.
#
# El formato tiene que acomodar información sobre otras lunas, por lo que debe ser genérico.
#
# En lugar de reemplazar las variables en una cadena larga como parte de un párrafo, utiliza la información para presentarla en un formato tabular. El resultado debería verse así:
#
# Gravity Facts about Ganymede
#
# -------------------------------------------------------------------------------
# Planet Name: Mars
# Gravity on Ganymede: 1.4300000000000002 m/s2

# %%
# Datos con los que vas a trabajar
name = "Moon"
gravity = 0.00162 # in kms
planet = "Earth"

# %% [markdown]
# Primero, crea un título para el texto. Debido a que este texto trata sobre la gravedad en la Tierra y la Luna, úsalo para crear un título significativo. Utiliza las variables en lugar de escribir.

# %%
title = f'La greverdad en la {planet} es muy diferente al de la {name} ya que en esta es de {gravity} kms'

print(title)
# Out:
# La greverdad en la Earth es muy diferente al de la Moon ya que en esta es de 0.00162 kms

# %% [markdown]
# Ahora crea una plantilla de cadena multilínea para contener el resto de la información. En lugar de usar kilómetros, debes convertir la distancia a metros multiplicando por 1,000.

# %%
hechos = f"""{'-'*80} 
Nombre del planeta: {planet} 
Gravedad en {name}: {gravity * 1000} m/s2 
"""
print(hechos)
# Out:
# --------------------------------------------------------------------------------
# Nombre del planeta: Earth
# Gravedad en Moon: 1.6199999999999999 m/s2

# %% [markdown]
# Finalmente, usa ambas variables para unir el título y los hechos.

# %%
template = f"""{title.title()} 
{hechos} """ 
print(template)
# Out:
# La Greverdad En La Earth Es Muy Diferente Al De La Moon Ya Que En Esta Es De 0.00162 Kms
# --------------------------------------------------------------------------------
# Nombre del planeta: Earth
# Gravedad en Moon: 1.6199999999999999 m/s2

# %% [markdown]
# Ahora usa información de una luna diferente para ver si la plantilla todavía funciona.
#
# Datos muestra:

# %%
planet = 'Marte '
gravity  = 0.00143
name = 'Ganímedes'

# %%
print(hechos)
# Out:
# --------------------------------------------------------------------------------
# Nombre del planeta: Earth
# Gravedad en Moon: 1.6199999999999999 m/s2

# %% [markdown]
# La salida no muestra información sobre Marte. Todavía muestra información sobre la Luna. Esto sucede porque las cadenas f están ansiosas en su evaluación, por lo que las variables una vez asignadas no se pueden reasignar. Para evitar este problema, vuelva a hacer la plantilla para utilizar .format():

# %%
nuevos_datos= """
Datos de Gravedad sobre: {nombre}
-------------------------------------------------------------------------------
Nombre del planeta: {planeta}
Gravedad en {nombre}: {gravedad} m/s2
"""
print(nuevos_datos.format(nombre=name, planeta=planet, gravedad=gravity))
# Out:
# Datos de Gravedad sobre: Ganímedes
# -------------------------------------------------------------------------------
# Nombre del planeta: Marte
# Gravedad en Ganímedes: 0.00143 m/s2

# %% [markdown]
# Debido a que .format() no permite expresiones, la gravedad en Ganímedes es incorrecta. Asegúrese de que la operación se realiza fuera de la plantilla de formato e imprima de nuevo para ver el resultado de trabajo.

# %%
print(nuevos_datos.format(nombre=name, planeta=planet, gravedad=gravity*1000))
# Out:
# Datos de Gravedad sobre: Ganímedes
# -------------------------------------------------------------------------------
# Nombre del planeta: Marte
# Gravedad en Ganímedes: 1.4300000000000002 m/s2
